# %% [markdown]
# <a href="https://colab.research.google.com/github/txrds/Blood-Glucose-Prediction-Competition/blob/main/Blood_Glucose_Prediction_Competition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/competitions/brist1d/overview

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
train_df = pd.read_csv('/content/gdrive/MyDrive/Projetos/Kaggle/BrisT1D Blood Glucose Prediction Competition/train.csv')
test_df = pd.read_csv('/content/gdrive/MyDrive/Projetos/Kaggle/BrisT1D Blood Glucose Prediction Competition/test.csv')
# Out:
# <ipython-input-3-5660b1340571>:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv('/content/gdrive/MyDrive/Projetos/Kaggle/BrisT1D Blood Glucose Prediction Competition/train.csv')

# %%
train_df.head()
# Out:
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  bg-5:20  bg-5:15  bg-5:10  bg-5:05  bg-5:00  bg-4:55  \
# 0      9.7      NaN      NaN      9.2      NaN      NaN      8.7      NaN
# 1      9.2      NaN      NaN      8.7      NaN      NaN      8.4      NaN
# 2      8.7      NaN      NaN      8.4      NaN      NaN      8.1      NaN
# 3      8.4      NaN      NaN      8.1      NaN      NaN      8.3      NaN
# 4      8.1      NaN      NaN      8.3      NaN      NaN      9.6      NaN
#
#    bg-4:50  bg-4:45  bg-4:40  bg-4:35  bg-4:30  bg-4:25  bg-4:20  bg-4:15  \
# ...

# %% [markdown]
# #Analise

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177024 entries, 0 to 177023
# Columns: 508 entries, id to bg+1:00
# dtypes: float64(433), object(75)
# memory usage: 686.1+ MB

# %%
pd.set_option('display.max_columns', None)

# %%
pd.reset_option('display.max_columns')

# %%
train_df.describe()
# Out:
#              bg-5:55        bg-5:50        bg-5:45        bg-5:40  \
# count  149770.000000  158533.000000  163364.000000  149766.000000
# mean        8.211018       8.230449       8.253291       8.210988
# std         2.852188       2.913438       2.945594       2.852090
# min         2.200000       2.200000       2.200000       2.200000
# 25%         6.100000       6.100000       6.100000       6.100000
# 50%         7.600000       7.600000       7.700000       7.600000
# 75%         9.800000       9.800000       9.800000       9.800000
# max        22.200000      25.100000      27.800000      22.200000
#
#              bg-5:35        bg-5:30        bg-5:25        bg-5:20  \
# count  158254.000000  163770.000000  149763.000000  157973.000000
# mean        8.229649       8.254083       8.211049       8.228888
# std         2.911313       2.947651       2.852212       2.909304
# min         2.200000       2.200000       2.200000       2.200000
# ...

# %%
train_df.isna().sum()
# Out:
# id                    0
# p_num                 0
# time                  0
# bg-5:55           27254
# bg-5:50           18491
#                   ...
# activity-0:15    174293
# activity-0:10    174287
# activity-0:05    174271
# activity-0:00    174287
# bg+1:00               0
# Length: 508, dtype: int64

# %%
#Proporção de Dados Faltantes: Avalie a proporção de valores ausentes por coluna
missing_data = train_df.isnull().mean().sort_values(ascending=False)
missing_data
# Out:
# activity-5:15    0.984680
# activity-4:15    0.984674
# activity-4:00    0.984663
# activity-3:45    0.984657
# activity-5:30    0.984657
#                    ...
# carbs-4:30       0.000000
# carbs-4:35       0.000000
# carbs-4:40       0.000000
# carbs-4:45       0.000000
# bg+1:00          0.000000
# Length: 508, dtype: float64

# %%
plt.figure(figsize=(19,6))
sns.heatmap(train_df.isnull(), cbar=False, cmap='viridis')
plt.show()

# %%
colunas_faltantes = train_df.columns[train_df.isnull().any()].tolist()
colunas_faltantes
# Out:
# ['bg-5:55',
#  'bg-5:50',
#  'bg-5:45',
#  'bg-5:40',
#  'bg-5:35',
#  'bg-5:30',
#  'bg-5:25',
#  'bg-5:20',
#  'bg-5:15',
#  'bg-5:10',
#  'bg-5:05',
#  'bg-5:00',
#  'bg-4:55',
#  'bg-4:50',
#  'bg-4:45',
#  'bg-4:40',
#  'bg-4:35',
#  'bg-4:30',
#  'bg-4:25',
#  'bg-4:20',
#  'bg-4:15',
#  'bg-4:10',
#  'bg-4:05',
#  'bg-4:00',
#  'bg-3:55',
#  'bg-3:50',
#  'bg-3:45',
#  'bg-3:40',
#  'bg-3:35',
#  'bg-3:30',
#  'bg-3:25',
#  'bg-3:20',
#  'bg-3:15',
#  'bg-3:10',
#  'bg-3:05',
#  'bg-3:00',
#  'bg-2:55',
#  'bg-2:50',
#  'bg-2:45',
#  'bg-2:40',
#  'bg-2:35',
#  'bg-2:30',
#  'bg-2:25',
#  'bg-2:20',
#  'bg-2:15',
#  'bg-2:10',
#  'bg-2:05',
#  'bg-2:00',
#  'bg-1:55',
#  'bg-1:50',
#  'bg-1:45',
#  'bg-1:40',
#  'bg-1:35',
#  'bg-1:30',
#  'bg-1:25',
#  'bg-1:20',
#  'bg-1:15',
#  'bg-1:10',
#  'bg-1:05',
#  'bg-1:00',
#  'bg-0:55',
#  'bg-0:50',
#  'bg-0:45',
#  'bg-0:40',
#  'bg-0:35',
#  'bg-0:30',
#  'bg-0:25',
#  'bg-0:20',
#  'bg-0:15',
#  'bg-0:10',
#  'bg-0:05',
# ...

# %%
colunas_numericas = train_df.select_dtypes(include=['float64','int64'])
media_dicionario = colunas_numericas.mean()[colunas_numericas.isnull().any()].to_dict()
media_dicionario
# Out:
# {}

# %%
# Selecionar apenas colunas numéricas
colunas_numericas = train_df.select_dtypes(include=['float64', 'int64'])

# Preencher os valores faltantes nas colunas numéricas com a média de cada coluna
train_df[colunas_numericas.columns] = colunas_numericas.fillna(colunas_numericas.mean())

train_df.head()
# Out:
#       id p_num      time   bg-5:55   bg-5:50  bg-5:45   bg-5:40   bg-5:35  \
# 0  p01_0   p01  06:10:00  8.211018  8.230449      9.6  8.210988  8.229649
# 1  p01_1   p01  06:25:00  8.211018  8.230449      9.7  8.210988  8.229649
# 2  p01_2   p01  06:40:00  8.211018  8.230449      9.2  8.210988  8.229649
# 3  p01_3   p01  06:55:00  8.211018  8.230449      8.7  8.210988  8.229649
# 4  p01_4   p01  07:10:00  8.211018  8.230449      8.4  8.210988  8.229649
#
#    bg-5:30   bg-5:25   bg-5:20  bg-5:15  bg-5:10  bg-5:05  bg-5:00   bg-4:55  \
# 0      9.7  8.211049  8.228888      9.2    8.211  8.22835      8.7  8.211187
# 1      9.2  8.211049  8.228888      8.7    8.211  8.22835      8.4  8.211187
# 2      8.7  8.211049  8.228888      8.4    8.211  8.22835      8.1  8.211187
# 3      8.4  8.211049  8.228888      8.1    8.211  8.22835      8.3  8.211187
# 4      8.1  8.211049  8.228888      8.3    8.211  8.22835      9.6  8.211187
#
# ...
